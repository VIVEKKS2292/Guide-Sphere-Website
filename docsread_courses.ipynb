# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

# %%
# Define the scope of access (can be readonly or readwrite)
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# %%
# Path to your credentials JSON file
credentials ={
  "type": "service_account",
  "project_id": "guidesphere",
  "private_key_id": "1149cc64b75a7ef6345b783fbe7729a82d40be19",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nrfZ6qUERkYXa3SXE58Mn8Vlc\n-----END PRIVATE KEY-----\n",
  "client_email": "guide-sphere-vivek-2292@guidesphere.iam.gserviceaccount.com",
  "client_id": "116909885100955444844",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/guide-sphere-vivek-2292%40guidesphere.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}

# %%
# Authenticate using service account credentials
credentials = ServiceAccountCredentials.from_json_keyfile_dict(credentials, scope)
client = gspread.authorize(credentials)

# %%
# Open the Google Sheets document
sheet = client.open_by_url("https://docs.google.com/spreadsheets/d/1FelQDvbaIFUhLUNsY0SrWazFCywDdrjhj5fI1t9gMBM/edit#gid=1389387669")
worksheet = sheet.get_worksheet(0)  # Assuming the data is in the first worksheet

# %%
# Read data into a pandas DataFrame
data = worksheet.get_all_records()
df = pd.DataFrame(data)

# %%
df.head()  # Print the first few rows of the DataFrame
# Out:
#                                           course_url  \
# 0  https://www.udemy.com/course/complete-python-b...
# 1  https://www.udemy.com/course/the-complete-web-...
# 2     https://www.udemy.com/course/100-days-of-code/
# 3  https://www.udemy.com/course/the-web-developer...
# 4  https://www.udemy.com/course/react-the-complet...
#
#                                           course_img   course_duration  \
# 0  https://img-c.udemycdn.com/course/240x135/5678...    22 total hours
# 1  https://img-c.udemycdn.com/course/240x135/1565...    62 total hours
# 2  https://img-c.udemycdn.com/course/240x135/2776...    58 total hours
# 3  https://img-c.udemycdn.com/course/240x135/6252...    74 total hours
# 4  https://img-c.udemycdn.com/course/240x135/1362...  68.5 total hours
#
#           course_price   course_price_original  \
# 0  Current price: ₹449  Original price: ₹3,099
# 1  Current price: ₹449  Original price: ₹3,099
# 2  Current price: ₹449  Original price: ₹3,099
# 3  Current price: ₹449  Original price: ₹3,099
# 4  Current price: ₹499  Original price: ₹3,499
#
#                                     course_instrutor  \
# 0                                      Jose Portilla
# 1                                      Dr. Angela Yu
# 2                                      Dr. Angela Yu
# 3                                        Colt Steele
# 4  Academind by Maximilian Schwarzmüller, Maximil...
#
#                                         course_title  \
# 0  The Complete Python Bootcamp From Zero to Hero...
# 1         The Complete 2024 Web Development Bootcamp
# 2  100 Days of Code: The Complete Python Pro Boot...
# 3                    The Web Developer Bootcamp 2024
# 4  React - The Complete Guide 2024 (incl. React R...
#
#                                    course_short_desc course_rating  \
# 0  Learn Python like a Professional  Start from t...           4.6
# 1  Become a Full-Stack Web Developer with just ON...           4.7
# 2  Master Python by building 100 projects in 100 ...           4.7
# 3  10 Hours of React just added. Become a Develop...           4.7
# 4  Dive in and learn React.js from scratch! Learn...           4.6
#
#   course_date course_language  \
# 0      7/2023         English
# 1      2/2024         English
# 2      1/2024         English
# 3      2/2024         English
# 4      1/2024         English
#
#                                  course_outcome_text  \
# 0  What you'll learn\nYou will learn how to lever...
# 1  What you'll learn\nBuild 16 web development pr...
# 2  What you'll learn\nYou will master the Python ...
# 3  What you'll learn\nThe ins and outs of HTML5, ...
# 4  What you'll learn\nLearn React from the ground...
#
#                                  course_outcome_html  \
# 0  <h2 class="ud-heading-xl what-you-will-learn--...
# 1  <h2 class="ud-heading-xl what-you-will-learn--...
# 2  <h2 class="ud-heading-xl what-you-will-learn--...
# 3  <h2 class="ud-heading-xl what-you-will-learn--...
# 4  <h2 class="ud-heading-xl what-you-will-learn--...
#
#                                    course_about_text  \
# 0  Become a Python Programmer and learn one of em...
# 1  Welcome to the Complete Web Development Bootca...
# 2  Welcome to the 100 Days of Code - The Complete...
# 3  Now with over 10 hours of React content.  Just...
# 4  This bestselling course has turned more than 8...
#
#                                    course_about_html course_id  \
# 0  <p><strong>Become a Python Programmer and lear...    c00001
# 1  <p>Welcome to the Complete Web Development Boo...    c00002
# 2  <p>Welcome to the 100 Days of Code - The Compl...    c00003
# 3  <p><strong>Now with over 10 hours of React con...    c00004
# 4  <p>This bestselling course has turned <strong>...    c00005
#
#                                  course_about_html_2
# 0
# 1
# 2  <p>Welcome to the 100 Days of Code - The Compl...
# 3
# 4

# %%
df.iloc[65:70]
# Out:
#                                            course_url  \
# 65  https://www.udemy.com/course/certified-tester-...
# 66  https://www.udemy.com/course/data-science-and-...
# 67         https://www.udemy.com/course/git-complete/
# 68     https://www.udemy.com/course/alteryx-bootcamp/
# 69  https://www.udemy.com/course/certified-kuberne...
#
#                                            course_img   course_duration  \
# 65  https://img-c.udemycdn.com/course/240x135/2693...  17.5 total hours
# 66  https://img-c.udemycdn.com/course/240x135/6715...    19 total hours
# 67  https://img-c.udemycdn.com/course/240x135/2216...   6.5 total hours
# 68  https://img-c.udemycdn.com/course/240x135/1248...   6.5 total hours
# 69  https://img-c.udemycdn.com/course/240x135/1988...  15.5 total hours
#
#            course_price   course_price_original  \
# 65  Current price: ₹649  Original price: ₹4,299
# 66  Current price: ₹649  Original price: ₹4,299
# 67  Current price: ₹499  Original price: ₹3,299
# 68  Current price: ₹449  Original price: ₹3,099
# 69  Current price: ₹449  Original price: ₹3,099
#
#                                      course_instrutor  \
# 65                                       Maged Koshty
# 66  Sundog Education by Frank Kane, Frank Kane, Su...
# 67                           Jason Taylor, John Myers
# 68                                     Hendrik Kleine
# 69  Mumshad Mannambeth, KodeKloud Training, Vijin ...
#
#                                          course_title  \
# 65  ISTQB Foundation Level (CTFL) V4 and V3.1 upda...
# 66  Machine Learning, Data Science and Generative ...
# 67  Git Complete: The definitive, step-by-step gui...
# 68                                   Alteryx Bootcamp
# 69  Kubernetes Certified Application Developer (CK...
#
#                                     course_short_desc course_rating  \
# 65  Be an ISTQB certified tester and Learn the bas...           4.4
# 66  Complete hands-on machine learning and AI tuto...           4.6
# 67  Go from zero to hero with Git source control s...           4.4
# 68  Learn Alteryx in as little as 4 hours with thi...           4.5
# 69  Learn concepts and practice for the Kubernetes...           4.7
#
#    course_date course_language  \
# 65      1/2024         English
# 66      2/2024         English
# 67      8/2022         English
# 68      2/2024         English
# 69      1/2024         English
#
#                                   course_outcome_text  \
# 65  What you'll learn\nPrepare for the ISTQB® foun...
# 66  What you'll learn\nBuild artificial neural net...
# 67  What you'll learn\nLearn the key concepts of t...
# 68  What you'll learn\nDevelop Alteryx Workflows\n...
# 69  What you'll learn\nKubernetes Certification\nD...
#
#                                   course_outcome_html  \
# 65  <h2 class="ud-heading-xl what-you-will-learn--...
# 66  <h2 class="ud-heading-xl what-you-will-learn--...
# 67  <h2 class="ud-heading-xl what-you-will-learn--...
# 68  <h2 class="ud-heading-xl what-you-will-learn--...
# 69  <h2 class="ud-heading-xl what-you-will-learn--...
#
#                                     course_about_text  \
# 65  The course has both the ISTQB Foundation Sylla...
# 66  New! Updated with extra content and activities...
# 67  Git Complete \n This course is designed to be ...
# 68  If you work in data analysis or business intel...
# 69  *** Updated for latest CKAD (2022) 1.27 versio...
#
#                                     course_about_html course_id  \
# 65  <p>The course has both the ISTQB&nbsp;Foundati...    c00066
# 66  <p><strong>New!&nbsp;<em>Updated</em></strong>...    c00067
# 67  <p><strong>Git Complete</strong> </p>\n<p> Thi...    c00068
# 68  <p>If you work in data analysis or business in...    c00069
# 69  <p><strong>*** Updated for latest CKAD (2022) ...    c00070
#
#                                   course_about_html_2
# 65  <p>The course has both the ISTQB&nbsp;Foundati...
# 66  <p><strong>New!&nbsp;<em>Updated</em></strong>...
# 67  <p><strong>Git Complete</strong> </p>\n<p> Thi...
# 68  <p>If you work in data analysis or business in...
# 69  <p><strong>*** Updated for latest CKAD (2022) ...

# %% [markdown]
# ## Performing Operations

# %%
df.columns
# Out:
# Index(['course_url', 'course_img', 'course_duration', 'course_price',
#        'course_price_original', 'course_instrutor', 'course_title',
#        'course_short_desc', 'course_rating', 'course_date', 'course_language',
#        'course_outcome_text', 'course_outcome_html', 'course_about_html',
#        'course_about_text', 'course_about_text2', 'course_about_html_2'],
#       dtype='object')

# %%
def longer_course_about_text(row):
    course_about_text = str(row['course_about_text'])  # Convert to string
    course_about_text2 = str(row['course_about_text2'])  # Convert to string
    if len(course_about_text) >= len(course_about_text2):
        return course_about_text
    else:
        return course_about_text2

# %%
df['course_about_text'] = df.apply(longer_course_about_text, axis=1)

# %%
def longer_course_about_html(row):
    course_about_html = str(row['course_about_html'])  # Convert to string
    course_about_html_2 = str(row['course_about_html_2'])  # Convert to string
    if len(course_about_html) >= len(course_about_html_2):
        return course_about_html
    else:
        return course_about_html_2

# %%
df['course_about_html'] = df.apply(longer_course_about_html, axis=1)

# %%
df = df[['course_url', 'course_img', 'course_duration', 'course_price',
       'course_price_original', 'course_instrutor', 'course_title',
       'course_short_desc', 'course_rating', 'course_date', 'course_language',
       'course_outcome_text', 'course_outcome_html', 'course_about_text',
       'course_about_html']]

# %%
len(df)
# Out:
# 1002

# %%
course_ids = ['c' + str(i).zfill(5) for i in range(1, len(df) + 1)]

# %%
df['course_id'] = course_ids

# %%
# Update data in the Google Sheets document
worksheet.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# {'spreadsheetId': '1FelQDvbaIFUhLUNsY0SrWazFCywDdrjhj5fI1t9gMBM',
#  'updatedRange': 'Highly_detailed!A1:P1003',
#  'updatedRows': 1003,
#  'updatedColumns': 16,
#  'updatedCells': 16048}

# %% [markdown]
# ##### Removing Last Updated part from course_date Column

# %%
# Remove "Last updated " and single quotes, and keep only the date part
df['course_date'] = df['course_date'].str.replace(r'Last updated ', '').str.strip("'")

# %%
# Update data in the Google Sheets document after removing Last Updated
worksheet.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# {'spreadsheetId': '1FelQDvbaIFUhLUNsY0SrWazFCywDdrjhj5fI1t9gMBM',
#  'updatedRange': 'Highly_detailed!A1:P1003',
#  'updatedRows': 1003,
#  'updatedColumns': 16,
#  'updatedCells': 16048}

# %%
df.head()
# Out:
#                                           course_url  \
# 0  https://www.udemy.com/course/complete-python-b...
# 1  https://www.udemy.com/course/the-complete-web-...
# 2     https://www.udemy.com/course/100-days-of-code/
# 3  https://www.udemy.com/course/the-web-developer...
# 4  https://www.udemy.com/course/react-the-complet...
#
#                                           course_img   course_duration  \
# 0  https://img-c.udemycdn.com/course/240x135/5678...    22 total hours
# 1  https://img-c.udemycdn.com/course/240x135/1565...    62 total hours
# 2  https://img-c.udemycdn.com/course/240x135/2776...    58 total hours
# 3  https://img-c.udemycdn.com/course/240x135/6252...    74 total hours
# 4  https://img-c.udemycdn.com/course/240x135/1362...  68.5 total hours
#
#           course_price   course_price_original  \
# 0  Current price: ₹449  Original price: ₹3,099
# 1  Current price: ₹449  Original price: ₹3,099
# 2  Current price: ₹449  Original price: ₹3,099
# 3  Current price: ₹449  Original price: ₹3,099
# 4  Current price: ₹499  Original price: ₹3,499
#
#                                     course_instrutor  \
# 0                                      Jose Portilla
# 1                                      Dr. Angela Yu
# 2                                      Dr. Angela Yu
# 3                                        Colt Steele
# 4  Academind by Maximilian Schwarzmüller, Maximil...
#
#                                         course_title  \
# 0  The Complete Python Bootcamp From Zero to Hero...
# 1         The Complete 2024 Web Development Bootcamp
# 2  100 Days of Code: The Complete Python Pro Boot...
# 3                    The Web Developer Bootcamp 2024
# 4  React - The Complete Guide 2024 (incl. React R...
#
#                                    course_short_desc course_rating  \
# 0  Learn Python like a Professional  Start from t...           4.6
# 1  Become a Full-Stack Web Developer with just ON...           4.7
# 2  Master Python by building 100 projects in 100 ...           4.7
# 3  10 Hours of React just added. Become a Develop...           4.7
# 4  Dive in and learn React.js from scratch! Learn...           4.6
#
#   course_date course_language  \
# 0  2023-07-01         English
# 1  2024-02-01         English
# 2  2024-01-01         English
# 3  2024-02-01         English
# 4  2024-01-01         English
#
#                                  course_outcome_text  \
# 0  What you'll learn\nYou will learn how to lever...
# 1  What you'll learn\nBuild 16 web development pr...
# 2  What you'll learn\nYou will master the Python ...
# 3  What you'll learn\nThe ins and outs of HTML5, ...
# 4  What you'll learn\nLearn React from the ground...
#
#                                  course_outcome_html  \
# 0  <h2 class="ud-heading-xl what-you-will-learn--...
# 1  <h2 class="ud-heading-xl what-you-will-learn--...
# 2  <h2 class="ud-heading-xl what-you-will-learn--...
# 3  <h2 class="ud-heading-xl what-you-will-learn--...
# 4  <h2 class="ud-heading-xl what-you-will-learn--...
#
#                                    course_about_text  \
# 0  Become a Python Programmer and learn one of em...
# 1  Welcome to the Complete Web Development Bootca...
# 2  Welcome to the 100 Days of Code - The Complete...
# 3  Now with over 10 hours of React content.  Just...
# 4  This bestselling course has turned more than 8...
#
#                                    course_about_html course_id  \
# 0  <p><strong>Become a Python Programmer and lear...    c00001
# 1  <p>Welcome to the Complete Web Development Boo...    c00002
# 2  <p>Welcome to the 100 Days of Code - The Compl...    c00003
# 3  <p><strong>Now with over 10 hours of React con...    c00004
# 4  <p>This bestselling course has turned <strong>...    c00005
#
#                                  course_about_html_2
# 0
# 1
# 2  <p>Welcome to the 100 Days of Code - The Compl...
# 3
# 4

# %% [markdown]
# ### Focusing on that Date conversion part

# %%
from datetime import datetime
def format_date(date):
    # Extract year and month from the datetime object
    year = str(date.year)
    month = str(date.month).zfill(2)  # Zero-padding for single-digit months
    # Format the date as 'mm/yyyy'
    formatted_date = f"{month}/{year}"
    return formatted_date

def clean_date(date_str):
    try:
        return pd.to_datetime(date_str, format='%m/%Y')
    except ValueError:
        return pd.NaT  # Return NaT for invalid dates

def get_recent_courses(courses):
    # Convert 'course_date' to datetime
    courses['course_date'] = pd.to_datetime(courses['course_date'], format='%m/%Y') 
    # Get current month and year
    current_date = datetime.now() 
    # Filter courses that are nearest or in the same month and year as the current month and year
    recent_courses = courses[courses['course_date'].dt.strftime('%m/%Y') <= current_date.strftime('%m/%Y')].sort_values(by='course_date', ascending=False).head(10)
    # Convert 'course_date' back to the original format
    courses['course_date'] = courses['course_date'].apply(format_date)
    courses['course_date'] = courses['course_date'].apply(clean_date)
    # Get the course titles of the recent courses
    # recent_course_titles = recent_courses['course_title'].tolist()
    # print(recent_courses)

# %%
get_recent_courses(df)
df['course_date'] = df['course_date'].apply(format_date)
df.head()
# Out:
#                                           course_url  \
# 0  https://www.udemy.com/course/complete-python-b...
# 1  https://www.udemy.com/course/the-complete-web-...
# 2     https://www.udemy.com/course/100-days-of-code/
# 3  https://www.udemy.com/course/the-web-developer...
# 4  https://www.udemy.com/course/react-the-complet...
#
#                                           course_img   course_duration  \
# 0  https://img-c.udemycdn.com/course/240x135/5678...    22 total hours
# 1  https://img-c.udemycdn.com/course/240x135/1565...    62 total hours
# 2  https://img-c.udemycdn.com/course/240x135/2776...    58 total hours
# 3  https://img-c.udemycdn.com/course/240x135/6252...    74 total hours
# 4  https://img-c.udemycdn.com/course/240x135/1362...  68.5 total hours
#
#           course_price   course_price_original  \
# 0  Current price: ₹449  Original price: ₹3,099
# 1  Current price: ₹449  Original price: ₹3,099
# 2  Current price: ₹449  Original price: ₹3,099
# 3  Current price: ₹449  Original price: ₹3,099
# 4  Current price: ₹499  Original price: ₹3,499
#
#                                     course_instrutor  \
# 0                                      Jose Portilla
# 1                                      Dr. Angela Yu
# 2                                      Dr. Angela Yu
# 3                                        Colt Steele
# 4  Academind by Maximilian Schwarzmüller, Maximil...
#
#                                         course_title  \
# 0  The Complete Python Bootcamp From Zero to Hero...
# 1         The Complete 2024 Web Development Bootcamp
# 2  100 Days of Code: The Complete Python Pro Boot...
# 3                    The Web Developer Bootcamp 2024
# 4  React - The Complete Guide 2024 (incl. React R...
#
#                                    course_short_desc course_rating  \
# 0  Learn Python like a Professional  Start from t...           4.6
# 1  Become a Full-Stack Web Developer with just ON...           4.7
# 2  Master Python by building 100 projects in 100 ...           4.7
# 3  10 Hours of React just added. Become a Develop...           4.7
# 4  Dive in and learn React.js from scratch! Learn...           4.6
#
#   course_date course_language  \
# 0     07/2023         English
# 1     02/2024         English
# 2     01/2024         English
# 3     02/2024         English
# 4     01/2024         English
#
#                                  course_outcome_text  \
# 0  What you'll learn\nYou will learn how to lever...
# 1  What you'll learn\nBuild 16 web development pr...
# 2  What you'll learn\nYou will master the Python ...
# 3  What you'll learn\nThe ins and outs of HTML5, ...
# 4  What you'll learn\nLearn React from the ground...
#
#                                  course_outcome_html  \
# 0  <h2 class="ud-heading-xl what-you-will-learn--...
# 1  <h2 class="ud-heading-xl what-you-will-learn--...
# 2  <h2 class="ud-heading-xl what-you-will-learn--...
# 3  <h2 class="ud-heading-xl what-you-will-learn--...
# 4  <h2 class="ud-heading-xl what-you-will-learn--...
#
#                                    course_about_text  \
# 0  Become a Python Programmer and learn one of em...
# 1  Welcome to the Complete Web Development Bootca...
# 2  Welcome to the 100 Days of Code - The Complete...
# 3  Now with over 10 hours of React content.  Just...
# 4  This bestselling course has turned more than 8...
#
#                                    course_about_html course_id  \
# 0  <p><strong>Become a Python Programmer and lear...    c00001
# 1  <p>Welcome to the Complete Web Development Boo...    c00002
# 2  <p>Welcome to the 100 Days of Code - The Compl...    c00003
# 3  <p><strong>Now with over 10 hours of React con...    c00004
# 4  <p>This bestselling course has turned <strong>...    c00005
#
#                                  course_about_html_2
# 0
# 1
# 2  <p>Welcome to the 100 Days of Code - The Compl...
# 3
# 4

# %% [markdown]
# ### Filling Out the Empty Cells And Short Cells

# %%
def fill_empty_outcomes(courses, fill_value="This Outcomes of the Course is not added"):
    courses['course_outcome_text'] = courses['course_outcome_text'].fillna(fill_value)
    return courses

# %%
df = fill_empty_outcomes(df)

# %%
# Update data in the Google Sheets document after removing Last Updated
worksheet.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# {'spreadsheetId': '1FelQDvbaIFUhLUNsY0SrWazFCywDdrjhj5fI1t9gMBM',
#  'updatedRange': 'Highly_detailed!A1:Q1070',
#  'updatedRows': 1070,
#  'updatedColumns': 17,
#  'updatedCells': 18190}

# %%
# Update data in the Google Sheets document
import gspread
from gspread_dataframe import set_with_dataframe
set_with_dataframe(worksheet, df)

# %%
# Update the 'course_outcome_text' column in the DataFrame
df['course_outcome_text'].fillna("This Outcomes of the Course is not added", inplace=True)
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_10532\437180682.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['course_outcome_text'].fillna("This Outcomes of the Course is not added", inplace=True)

# %%
# Convert the DataFrame back to a list of lists
updated_data = [df.columns.tolist()] + df.values.tolist()

# Clear the existing data in the worksheet
worksheet.clear()

# Update the data in the worksheet
worksheet.update(updated_data)
# Out:
# {'spreadsheetId': '1FelQDvbaIFUhLUNsY0SrWazFCywDdrjhj5fI1t9gMBM',
#  'updatedRange': 'Highly_detailed!A1:Q1070',
#  'updatedRows': 1070,
#  'updatedColumns': 17,
#  'updatedCells': 18190}

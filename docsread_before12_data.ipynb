# %% [markdown]
# ## Youtube Data

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from pymongo import MongoClient
import pandas as pd
# Out:
# C:\Users\vivek\AppData\Local\Temp\ipykernel_14128\4168040130.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Define the scope of access (can be readonly or readwrite)
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# %%
# Path to your credentials JSON file
credentials ={
  "type": "service_account",
  "project_id": "guidesphere",
  "private_key_id": "1149cc64b75a7ef6345b783fbe7729a82d40be19",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nrfZ6qUERkYXa3SXE58Mn8Vlc\n-----END PRIVATE KEY-----\n",
  "client_email": "guide-sphere-vivek-2292@guidesphere.iam.gserviceaccount.com",
  "client_id": "116909885100955444844",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/guide-sphere-vivek-2292%40guidesphere.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}

# %%
# Authenticate using service account credentials
credentials = ServiceAccountCredentials.from_json_keyfile_dict(credentials, scope)
client = gspread.authorize(credentials)

# %%
# Open the Google Sheets document
sheet = client.open_by_url("https://docs.google.com/spreadsheets/d/1PiDB-S1DIm4jxsNfpIQbZ6OWsA2yg14cpHkqqqeyakY/edit#gid=0")
worksheet = sheet.get_worksheet(0)  # Assuming the data is in the first worksheet

# %%
# Read data into a pandas DataFrame
data = worksheet.get_all_records()

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                 yt_img  \
# 0    https://i.ytimg.com/vi/6AImCqiv7UY/hq720.jpg?s...
# 1    https://i.ytimg.com/vi/6AImCqiv7UY/hq720.jpg?s...
# 2    https://i.ytimg.com/vi/6AImCqiv7UY/hq720.jpg?s...
# 3    https://i.ytimg.com/vi/6AImCqiv7UY/hq720.jpg?s...
# 4    https://i.ytimg.com/vi/6AImCqiv7UY/hq720.jpg?s...
# ..                                                 ...
# 209  https://i.ytimg.com/vi/XYRTznW2wrI/hq720.jpg?s...
# 210  https://i.ytimg.com/vi/UpiZZxTrtSI/hqdefault.j...
# 211  https://i.ytimg.com/vi/WDZUYiCq77U/hq720.jpg?s...
# 212  https://i.ytimg.com/vi/ezsF7bQKnwA/hq720.jpg?s...
# 213  https://i.ytimg.com/vi/hwjRqvMOTvQ/hq720.jpg?s...
#
#                                                 yt_url yt_duration price  \
# 0     https://youtu.be/6AImCqiv7UY?si=2AlcbC5hzLil0SJ5   1.4 hours  free
# 1     https://youtu.be/T9DgvXpCnwo?si=bqI1TzuSug0Id_fC   1.5 hours  free
# 2    https://youtube.com/playlist?list=PLhf4hr_x5Xy...   14 videos  free
# 3    https://youtube.com/playlist?list=PLhf4hr_x5Xy...   21 videos  free
# 4    https://youtube.com/playlist?list=PLr6TOxpiWwu...    9 videos  free
# ..                                                 ...         ...   ...
# 209  https://www.youtube.com/playlist?list=PLVLoWQF...   31 videos  free
# 210  https://www.youtube.com/playlist?list=PLag1CXT...    9 videos  free
# 211  https://www.youtube.com/playlist?list=PLhf4hr_...   10 videos  free
# 212   https://www.youtube.com/watch?v=ezsF7bQKnwA&t=1s     5 hours  free
# 213        https://www.youtube.com/watch?v=hwjRqvMOTvQ     5 hours  free
#
#     origianl_price              yt_instructor  \
# 0             free             Shobhit Nirwan
# 1             free                     Exphub
# 2             free                    Vedantu
# 3             free                    Vedantu
# 4             free                  cbseclass
# ..             ...                        ...
# 209           free              Magnet Brains
# 210           free     Unacademy Class 9 & 10
# 211           free               Vedantu 9&10
# 212           free  Physics Wallah Foundation
# 213           free  Physics Wallah Foundation
#
#                                               yt_title  \
# 0    Trigonometry Class 10 in One Shot | Class 10 M...
# 1    Life Processes Complete Chapter| CLASS 10 Scie...
# 2    Basics to Advanced: Maths CBSE Class 10 Polyno...
# 3      Trigonometry Class 10 (Umang Series) - Playlist
# 4    Class 10 Maths NCERT Ch 5 Arithmetic Progressions
# ..                                                 ...
# 209  Class 10 Maths Chapter 10 (Circles) NCERT CBSE...
# 210  Circles - Playlist | class 10 | Unacademy Foun...
# 211  Circles Class 10 - Playlist - CBSE Class 10 Ma...
# 212  CIRCLES in 1 Shot FULL CHAPTER COVERAGE (Conce...
# 213     CIRCLES - in 1 Shot || Class -10th Board Exams
#
#                                          yt_short_desc  yt_course_rating  \
# 0    Whether you're looking for a comprehensive ove...               4.3
# 1    In this video, we dive deep into the fascinati...               4.1
# 2    In this CBSE Class 10 Maths Bridge Course 2022...               4.2
# 3    Trigonometry Class 10 playlist! Dive into the ...               4.4
# 4    Join us as we explore the fundamentals of AP, ...               4.1
# ..                                                 ...               ...
# 209  This playlist is taught by Magnet Brains on co...               4.0
# 210  This playlist is taught by Unacademy Class 9 &...               4.0
# 211  This playlist is taught by Vedantu 9&10 on con...               4.0
# 212  This session is taught by Physics Wallah Found...               4.0
# 213  This session is taught by Physics Wallah Found...               4.0
#
#      yt_date yt_language   yt_subject  yt_class  \
# 0    08/2023       Hindi  Mathematics        10
# 1    09/2023       Hindi      Science        10
# 2    05/2021       Hindi  Mathematics        10
# 3    08/2019       Hindi  Mathematics        10
# 4    07/2020       Hindi  Mathematics        10
# ..       ...         ...          ...       ...
# 209  01/2022       Hindi  Mathematics        10
# 210  11/2019       Hindi  Mathematics        10
# 211  12/2021       Hindi  Mathematics        10
# 212  01/2024       Hindi  Mathematics        10
# 213  01/2023       Hindi  Mathematics        10
#
#                                               yt_about
# 0    It includes video lectures (resource 1), pract...
# 1       It includes details of different life proccess
# 2    Explains the basics of polynomials, including ...
# 3    We cover Chapter 8 of CBSE Class 10 Maths, pro...
# 4    In this video you will learn about concept of ...
# ..                                                 ...
# 209                                          Not Added
# 210                                          Not Added
# 211                                          Not Added
# 212                                          Not Added
# 213                                          Not Added
#
# [214 rows x 14 columns]

# %%
# Generate the entries for the yt_id column
yt_ids = ['y{:05d}'.format(i) for i in range(1, len(df) + 1)]

# %%
# Add the yt_id column to the DataFrame
df['yt_id'] = yt_ids

# %%
# Convert the DataFrame back to a list of lists
updated_data = [df.columns.tolist()] + df.values.tolist()

# Clear the existing data in the worksheet
worksheet.clear()

# Update the data in the worksheet
worksheet.update(updated_data)
# Out:
# {'spreadsheetId': '1PiDB-S1DIm4jxsNfpIQbZ6OWsA2yg14cpHkqqqeyakY',
#  'updatedRange': 'Sheet1!A1:O215',
#  'updatedRows': 215,
#  'updatedColumns': 15,
#  'updatedCells': 3225}

# %% [markdown]
# ## Websites Data

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from pymongo import MongoClient
import pandas as pd

# %%
# Define the scope of access (can be readonly or readwrite)
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# %%
# Path to your credentials JSON file
credentials ={
  "type": "service_account",
  "project_id": "guidesphere",
  "private_key_id": "1149cc64b75a7ef6345b783fbe7729a82d40be19",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nrfZ6qUERkYXa3SXE58Mn8Vlc\n-----END PRIVATE KEY-----\n",
  "client_email": "guide-sphere-vivek-2292@guidesphere.iam.gserviceaccount.com",
  "client_id": "116909885100955444844",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/guide-sphere-vivek-2292%40guidesphere.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}

# %%
# Authenticate using service account credentials
credentials = ServiceAccountCredentials.from_json_keyfile_dict(credentials, scope)
client = gspread.authorize(credentials)

# %%
# Open the Google Sheets document
sheet = client.open_by_url("https://docs.google.com/spreadsheets/d/1fR6dfZx0WlR6zGVEfbXqb3dmHStlVRBDQvGurgAkce4/edit#gid=0")
worksheet = sheet.get_worksheet(0)  # Assuming the data is in the first worksheet

# %%
# Read data into a pandas DataFrame
data = worksheet.get_all_records()

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                                web_url  \
# 0    https://byjus.com/maths/real-numbers-for-class...
# 1     https://byjus.com/maths/polynomial-for-class-10/
# 2    https://byjus.com/cbse-notes/cbse-class-10-mat...
# 3    https://byjus.com/maths/quadratic-equation-for...
# 4    https://byjus.com/maths/arithmetic-progression...
# ..                                                 ...
# 195  https://www.geeksforgeeks.org/cbse-class-12-ch...
# 196  https://www.geeksforgeeks.org/cbse-class-12-ch...
# 197  https://www.geeksforgeeks.org/cbse-class-12-ch...
# 198  https://www.geeksforgeeks.org/cbse-class-12-ch...
# 199  https://www.geeksforgeeks.org/cbse-class-12-ch...
#
#                                                web_img   web_platform  \
# 0    https://logos-world.net/wp-content/uploads/202...         Byju's
# 1    https://logos-world.net/wp-content/uploads/202...         Byju's
# 2    https://logos-world.net/wp-content/uploads/202...         Byju's
# 3    https://logos-world.net/wp-content/uploads/202...         Byju's
# 4    https://logos-world.net/wp-content/uploads/202...         Byju's
# ..                                                 ...            ...
# 195  https://media.geeksforgeeks.org/wp-content/cdn...  GeeksforGeeks
# 196  https://media.geeksforgeeks.org/wp-content/cdn...  GeeksforGeeks
# 197  https://media.geeksforgeeks.org/wp-content/cdn...  GeeksforGeeks
# 198  https://media.geeksforgeeks.org/wp-content/cdn...  GeeksforGeeks
# 199  https://media.geeksforgeeks.org/wp-content/cdn...  GeeksforGeeks
#
#                                              web_title  \
# 0               Real Numbers Class 10 Notes: Chapter 1
# 1                 Polynomial Class 10 Notes: Chapter 2
# 2    Pair of Linear Equations in Two Variables Clas...
# 3          Quadratic Equation Class 10 Notes Chapter 4
# 4                Arithmetic Progression Class 10 Notes
# ..                                                 ...
# 195                       Chapter 5: Surface Chemistry
# 196  Chapter 6: General Principles and Processes of...
# 197                    Chapter 7: The p-Block Elements
# 198          Chapter 11: Alcohols, Phenols, and Ethers
# 199                 Chapter 8: d- and f-Block Elements
#
#                                         web_short_desc  web_subject  \
# 0    This tutorial is designed by Byju's on Concept...  Mathematics
# 1    CBSE Class 10 Maths Chapter 2 Polynomial Notes...  Mathematics
# 2    CBSE Class 10 Maths Chapter 3 Pairs of Linear ...  Mathematics
# 3    In this article, you will learn the concept of...  Mathematics
# 4    Get the complete notes on arithmetic progressi...  Mathematics
# ..                                                 ...          ...
# 195  This tutorial is designed by GeeksforGeeks Wal...    Chemistry
# 196  This tutorial is designed by GeeksforGeeks Wal...    Chemistry
# 197  This tutorial is designed by GeeksforGeeks Wal...    Chemistry
# 198  This tutorial is designed by GeeksforGeeks Wal...    Chemistry
# 199  This tutorial is designed by GeeksforGeeks Wal...    Chemistry
#
#      web_class web_language
# 0           10      English
# 1           10      English
# 2           10      English
# 3           10      English
# 4           10      English
# ..         ...          ...
# 195         12      English
# 196         12      English
# 197         12      English
# 198         12      English
# 199         12      English
#
# [200 rows x 8 columns]

# %%
# Generate the entries for the yt_id column
web_ids = ['w{:05d}'.format(i) for i in range(1, len(df) + 1)]

# %%
# Add the yt_id column to the DataFrame
df['web_id'] = web_ids

# %%
# Convert the DataFrame back to a list of lists
updated_data = [df.columns.tolist()] + df.values.tolist()

# Clear the existing data in the worksheet
worksheet.clear()

# Update the data in the worksheet
worksheet.update(updated_data)
# Out:
# {'spreadsheetId': '1fR6dfZx0WlR6zGVEfbXqb3dmHStlVRBDQvGurgAkce4',
#  'updatedRange': 'Sheet1!A1:I201',
#  'updatedRows': 201,
#  'updatedColumns': 9,
#  'updatedCells': 1809}

# %% [markdown]
# ## Books Data

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from pymongo import MongoClient
import pandas as pd

# %%
# Define the scope of access (can be readonly or readwrite)
scope = ['https://spreadsheets.google.com/feeds','https://www.googleapis.com/auth/drive']

# %%
# Path to your credentials JSON file
credentials ={
  "type": "service_account",
  "project_id": "guidesphere",
  "private_key_id": "1149cc64b75a7ef6345b783fbe7729a82d40be19",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nrfZ6qUERkYXa3SXE58Mn8Vlc\n-----END PRIVATE KEY-----\n",
  "client_email": "guide-sphere-vivek-2292@guidesphere.iam.gserviceaccount.com",
  "client_id": "116909885100955444844",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/guide-sphere-vivek-2292%40guidesphere.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}

# %%
# Authenticate using service account credentials
credentials = ServiceAccountCredentials.from_json_keyfile_dict(credentials, scope)
client = gspread.authorize(credentials)

# %%
# Open the Google Sheets document
sheet = client.open_by_url("https://docs.google.com/spreadsheets/d/18JSRn7gSWtQoMX75CJsKDDk4QGZEI6AZEGGImlxzBQQ/edit#gid=226312399")
worksheet = sheet.get_worksheet(0)  # Assuming the data is in the first worksheet

# %%
# Read data into a pandas DataFrame
data = worksheet.get_all_records()

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#                                            book_title  \
# 0   1st Language English Series Sslc All 6 Subject...
# 1   Subhas Super Companion 6 In 1 Class 7th Std : ...
# 2   Sslc Student Study Guide Eng/1 Kan/2 Hin/3 Sci...
# 3       Vignana Sslc Exam Sp 15 Model Question Papers
# 4   Science 7th Std Honest Success Series Target 100%
# 5   Sslc Student Study Guide Km: Kan/1 Eng/2 Hind/...
# 6   9 Standard English 1st Language Work Book Cce ...
# 7           9 Standard English Work Book 2nd Language
# 8   10th Std Hindi 3rd Language Work Book + 4 Mock...
# 9          Vignana 10th Std Super Companion Made Easy
# 3   by A Chandrakanthamani, Cambridge Publishing C...        ₹60
# 4   by A Chandrakanthamani, Cambridge Publishing C...        ₹60
# 5              by Lv Venkata Reddy, Sunstar Publisher       ₹750
# 6                                 by Na, Raos Academy       ₹120
# 7                       by By Hiriyanna, Raos Academy       ₹120
# 8                        by Kusuma Ajay, Raos Academy       ₹120
# 9       by Lalitha K Madduru, Subhas Publishing House       ₹170
# 10     by P Pavithra, Cambridge Publishing Co Pvt Ltd       ₹150
# 11             by Jayanthi Suresh, Shiva Publications       ₹149
# 12                         by Katyayini, Raos Academy       ₹108
# 13  by Prabhukumar Bk, Cambridge Publishing Co Pvt...        ₹90
# 14                 by R Veni, Subhas Publishing House       ₹195
# 15                 by V Raju, Subhas Publishing House       ₹126
# 16                     by Na, Subhas Publishing House       ₹580
# 17                     by Na, Subhas Publishing House       ₹740
# 18            by Km Vishwanatha Marthur, Raos Academy       ₹180
# 19                            by Na, Vikram Prakashan       ₹720
# 20  by A Chandrakanthamani, Cambridge Publishing C...       ₹108
# 21  by Cb Ahobala Rao,R Sushma, Cambridge Publishi...       ₹250
# 22             by Na, Cambridge Publishing Co Pvt Ltd        ₹90
# 23                            by Na, Mcc Publications       ₹170
# 24  by A Chandrakanth Mani, Cambridge Publishing C...       ₹150
# 25             by Na, Cambridge Publishing Co Pvt Ltd        ₹70
# 26  by Bhanumati S Rao, Cambridge Publishing Co Pv...       ₹750
# 27  by Bhanumathi S Rao, Cambridge Publishing Co P...       ₹750
# 28  by Prabhukumar Bk, Cambridge Publishing Co Pvt...       ₹495
# 29            by Gs Usharani, Subhas Publishing House       ₹120
# 30                            by Na, Mcc Publications       ₹160
# 31                            by Na, Mcc Publications       ₹140
# 32      by Sc Manjunath,Shivakumar, Sunstar Publisher       ₹250
# 33                by Na, Zen Educational Technologies       ₹224
# 34          by Parveen Taj K, Subhas Publishing House       ₹475
# 35                by Na, Zen Educational Technologies       ₹178
# 36     by Swati Mehrotra, Acevision Publisher Pvt.Ltd       ₹240
# 37        by Rajamma, Cambridge Publishing Co Pvt Ltd        ₹60
# 38  by B Lakshmi Singh, Cambridge Publishing Co Pv...        ₹80
# 39  by Chandrakanthamani, Cambridge Publishing Co ...        ₹60
# 40  by A Chandrakanthamani, Cambridge Publishing C...        ₹60
# 41                     by Hd Suma, Shiva Publications       ₹259
# 42               by K Parveen Taj, Shiva Publications       ₹179
# 43                      by V Raju, Shiva Publications       ₹159
# 44                    by Kanchana S Rao, Raos Academy       ₹108
# 45                            by Na, Mcc Publications       ₹130
# 46  by Lokeshappa K,Kh Manjunatha, Shiva Publications       ₹239
# 47  by Bk Prabhu Kumar, Cambridge Publishing Co Pv...       ₹350
# 48  by Prabhukumar Bk, Cambridge Publishing Co Pvt...       ₹450
# 49                   by Hs Anupama, Sunstar Publisher       ₹113
# 50                 by N Manjunath, Shiva Publications       ₹239
# 51  by A Chandrakanth Mani, Cambridge Publishing C...       ₹150
# 52                 by R Veni, Subhas Publishing House       ₹200
# 53                  by Poornima Nadiger, Raos Academy       ₹140
# 54         by Padmanabha Hunagund, Shiva Publications       ₹179
# 55       by K Parveen Taj,Kv Ramanan, Kpl Publication       ₹160
# 56                            by Na, Mcc Publications       ₹160
# 57                         by Na, V-Care Publications       ₹280
# 58                by Na, Zen Educational Technologies       ₹188
# 59                by Antony Oliver, Sunstar Publisher       ₹125
#
#                  book_store
# 0   Sapna Book Store, Hubli
# 1   Sapna Book Store, Hubli
# 2   Sapna Book Store, Hubli
# 3   Sapna Book Store, Hubli
# 4   Sapna Book Store, Hubli
# 5   Sapna Book Store, Hubli
# 6   Sapna Book Store, Hubli
# 7   Sapna Book Store, Hubli
# 8   Sapna Book Store, Hubli
# 9   Sapna Book Store, Hubli
# 10  Sapna Book Store, Hubli
# 11  Sapna Book Store, Hubli
# 12  Sapna Book Store, Hubli
# 13  Sapna Book Store, Hubli
# 14  Sapna Book Store, Hubli
# 15  Sapna Book Store, Hubli
# 16  Sapna Book Store, Hubli
# 17  Sapna Book Store, Hubli
# 18  Sapna Book Store, Hubli
# 19  Sapna Book Store, Hubli
# 20  Sapna Book Store, Hubli
# 21  Sapna Book Store, Hubli
# 22  Sapna Book Store, Hubli
# 23  Sapna Book Store, Hubli
# 24  Sapna Book Store, Hubli
# 25  Sapna Book Store, Hubli
# 26  Sapna Book Store, Hubli
# 27  Sapna Book Store, Hubli
# 28  Sapna Book Store, Hubli
# 29  Sapna Book Store, Hubli
# 30  Sapna Book Store, Hubli
# 31  Sapna Book Store, Hubli
# 32  Sapna Book Store, Hubli
# 33  Sapna Book Store, Hubli
# 34  Sapna Book Store, Hubli
# 35  Sapna Book Store, Hubli
# 36  Sapna Book Store, Hubli
# 37  Sapna Book Store, Hubli
# 38  Sapna Book Store, Hubli
# 39  Sapna Book Store, Hubli
# 40  Sapna Book Store, Hubli
# 41  Sapna Book Store, Hubli
# 42  Sapna Book Store, Hubli
# 43  Sapna Book Store, Hubli
# 44  Sapna Book Store, Hubli
# 45  Sapna Book Store, Hubli
# 46  Sapna Book Store, Hubli
# 47  Sapna Book Store, Hubli
# 48  Sapna Book Store, Hubli
# 49  Sapna Book Store, Hubli
# 50  Sapna Book Store, Hubli
# 51  Sapna Book Store, Hubli
# 52  Sapna Book Store, Hubli
# 53  Sapna Book Store, Hubli
# 54  Sapna Book Store, Hubli
# 55  Sapna Book Store, Hubli
# 56  Sapna Book Store, Hubli
# 57  Sapna Book Store, Hubli
# 58  Sapna Book Store, Hubli
# 59  Sapna Book Store, Hubli

# %%
# Generate the entries for the yt_id column
book_ids = ['b{:05d}'.format(i) for i in range(1, len(df) + 1)]

# %%
# Add the yt_id column to the DataFrame
df['book_id'] = book_ids

# %%
# Convert the DataFrame back to a list of lists
updated_data = [df.columns.tolist()] + df.values.tolist()

# Clear the existing data in the worksheet
worksheet.clear()

# Update the data in the worksheet
worksheet.update(updated_data)
# Out:
# {'spreadsheetId': '18JSRn7gSWtQoMX75CJsKDDk4QGZEI6AZEGGImlxzBQQ',
#  'updatedRange': "'10th books'!A1:G61",
#  'updatedRows': 61,
#  'updatedColumns': 7,
#  'updatedCells': 427}
